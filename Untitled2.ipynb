# %%
import matplotlib.pyplot as plt
import easyocr
import cv2
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])

# %%
Image('Image1.png')

# %%
output = reader.readtext('Image1.png')

# %%
output
# Out:
# [([[3, 3], [67, 3], [67, 16], [3, 16]], 'Positidti', 0.2597034210584088),
#  ([[79, 3], [143, 3], [143, 16], [79, 16]], '8097 ,5d6', 0.10284171132496776),
#  ([[153, 1], [223, 1], [223, 16], [153, 16]],
#   '4527 ,196,',
#   0.6685744467405279),
#  ([[229, 1], [285, 1], [285, 16], [229, 16]], '43,495]1', 0.15420338365479005)]

# %%
Image('Image0.png')

# %%
output1 = reader.readtext('Image0.png')
output1
# Out:
# [([[3, 1], [143, 1], [143, 16], [3, 16]],
#   'Position [8305,173',
#   0.48816955457383965),
#  ([[153, 0], [285, 0], [285, 16], [153, 16]],
#   '4933,286 , 193,734',
#   0.8798394164274932)]

# %%
Image('Image2.png')

# %%
output2 = reader.readtext('Image2.png')
output2
# Out:
# [([[1, 3], [65, 3], [65, 16], [1, 16]], 'Position', 0.9975786288151297),
#  ([[69, 3], [109, 3], [109, 16], [69, 16]], '[8345', 0.9082504153887815),
#  ([[113, 3], [145, 3], [145, 16], [113, 16]], '646 ,', 0.9759423514009077),
#  ([[151, 3], [185, 3], [185, 16], [151, 16]], '4870', 0.9999698400497437),
#  ([[189, 3], [221, 3], [221, 16], [189, 16]], '666 ,', 0.9231410919390441),
#  ([[227, 1], [285, 1], [285, 16], [227, 16]], '183,369]', 0.9645893617980851)]

# %%
Image('Image3.png')

# %%
output3 = reader.readtext('Image3.png')
output3
# Out:
# [([[1, 1], [65, 1], [65, 15], [1, 15]], 'Pogitig', 0.4267026502067328),
#  ([[71, 1], [141, 1], [141, 16], [71, 16]], '[7374,858', 0.3859281371104942),
#  ([[151, 0], [221, 0], [221, 16], [151, 16]], '4458.203,', 0.6064258188469587),
#  ([[227, 0], [275, 0], [275, 16], [227, 16]], '#uUL', 0.13063806295394897)]

# %%
Image('Image4.png')

# %%
output4 = reader.readtext('Image4.png')
output4
# Out:
# [([[1, 0], [63, 0], [63, 13], [1, 13]], 'Posisioh', 0.17613550418248217),
#  ([[69, 0], [109, 0], [109, 13], [69, 13]], '[8464', 0.5846920129074483),
#  ([[113, 0], [139, 0], [139, 13], [113, 13]], '930', 0.9999889191002438),
#  ([[149, 0], [183, 0], [183, 13], [149, 13]], '4200', 0.9834847450256348),
#  ([[225, 0], [251, 0], [251, 13], [225, 13]], '131', 0.36670728938142977),
#  ([[255, 0], [285, 0], [285, 13], [255, 13]], '5641', 0.3240540325641632)]

# %%
Image('positions.png')

# %%
output5 = reader.readtext('positions.png')
output5
# Out:
# [([[3, 1], [111, 1], [111, 17], [3, 17]],
#   'Position [8305',
#   0.8900897107290657),
#  ([[115, 1], [141, 1], [141, 15], [115, 15]], '173', 0.9999542999976712),
#  ([[153, 0], [223, 0], [223, 15], [153, 15]],
#   '4933,286 ,',
#   0.8729033989792192),
#  ([[229, 0], [285, 0], [285, 17], [229, 17]], '193,734', 0.814465327397503),
#  ([[3, 19], [43, 19], [43, 33], [3, 33]], 'Posit', 0.8747942586851957),
#  ([[73, 19], [143, 19], [143, 33], [73, 33]],
#   '(3u97 , 535',
#   0.148289803139627),
#  ([[153, 17], [223, 17], [223, 35], [153, 35]],
#   '4527.,196 ,',
#   0.11468178348699039),
#  ([[229, 17], [277, 17], [277, 33], [229, 33]], '43,495', 0.7092256907804577),
#  ([[1, 35], [65, 35], [65, 51], [1, 51]], 'Position', 0.9982614063188129),
#  ([[71, 35], [109, 35], [109, 49], [71, 49]], '[8345', 0.9932063862496591),
#  ([[113, 35], [141, 35], [141, 49], [113, 49]], '646', 0.9993980074980766),
#  ([[151, 33], [185, 33], [185, 49], [151, 49]], '4870', 0.9998137354850769),
# ...
